# %%
# Load the lib needed
import numpy as np
import pandas as pd
warnings.filterwarnings("ignore")

card = pd.read_csv('./reshaped_data/card_id_not_by_month.csv',index_col='id')
borrow = pd.read_csv('./reshaped_data/borrow_total.csv',index_col='id')
lib = pd.read_csv('./reshaped_data/lib_times.csv',index_col='id')
score = pd.read_csv('./reshaped_data/score_data_reshaped.csv',index_col='id')
data = pd.concat([lib,borrow,card],axis=1)

# %%
data.head()
# Out:
#     lib_times  borrow_total   con_val   其他    图书馆       开水   教务处   文印中心  校医院  \
# id
# 0        16.0           NaN       NaN  NaN    NaN      NaN   NaN    NaN  NaN
# 1         2.0           NaN   5884.19  0.0  270.6   262.79  29.3  96.40  0.0
# 6         5.0           2.0   6284.83  0.0    2.2   839.01   0.0  14.52  0.0
# 7        91.0          28.0  11796.38  0.0   88.3  1033.74  11.4  10.30  0.0
# 8         NaN           NaN  10816.50  0.0  403.3  2381.52   0.0   2.00  0.0
#
#          校车    洗衣房     淋浴       超市       食堂
# id
# 0       NaN    NaN    NaN      NaN      NaN
# 1    116.40  34.80  21.50   506.60  4545.80
# 6     99.78   2.52   9.10   701.60  4616.10
# 7    602.64  54.00  21.40  1341.15  8633.45
# 8   2143.85   4.50  39.33    10.00  5832.00

# %%
data.isnull().sum()
# Out:
# lib_times       5205
# borrow_total    7336
# con_val            3
# 其他                 3
# 图书馆                3
# 开水                 3
# 教务处                3
# 文印中心               3
# 校医院                3
# 校车                 3
# 洗衣房                3
# 淋浴                 3
# 超市                 3
# 食堂                 3
# dtype: int64

# %%
data.fillna(data.mean(),inplace=True)
data.isnull().sum()
# Out:
# lib_times       0
# borrow_total    0
# con_val         0
# 其他              0
# 图书馆             0
# 开水              0
# 教务处             0
# 文印中心            0
# 校医院             0
# 校车              0
# 洗衣房             0
# 淋浴              0
# 超市              0
# 食堂              0
# dtype: int64

# %% [markdown]
# #导入训练集和测试集合

# %%
ID_test = pd.read_csv('./test/subsidy_final_test.txt',header=None,encoding='utf-16')
ID_train = pd.read_csv('./reshaped_data/score_data_reshaped.csv')
#Set columns of the test dataset
ID_test.columns=['id']

# %%
ID_test.head()
# Out:
#    id
# 0   6
# 1   7
# 2  12
# 3  13
# 4  14

# %%
ID_train.head()
# Out:
#    id  score_rank
# 0   0           1
# 1   1           1
# 2   8           5
# 3   9           5
# 4  10           1

# %%
x_train = data.loc[ID_train.id, :]
y_train = score.score_rank
x_test = data.loc[ID_test.id,:]

# %%
x_train.head()
# Out:
#      lib_times  borrow_total       con_val         其他        图书馆           开水  \
# id
# 0    16.000000     31.597342   7953.319141   2.310903  160.46791   829.124677
# 1     2.000000     31.597342   5884.190000   0.000000  270.60000   262.790000
# 8   124.725151     31.597342  10816.500000   0.000000  403.30000  2381.520000
# 9   124.725151     31.597342  14146.100000  61.130000  111.93000  4606.780000
# 10    4.000000     31.597342   5889.190000   0.000000  272.60000   743.400000
#
#           教务处        文印中心       校医院           校车        洗衣房          淋浴  \
# id
# 0   15.720311   23.694739  4.371123   347.509772  58.996781  115.959425
# 1   29.300000   96.400000  0.000000   116.400000  34.800000   21.500000
# 8    0.000000    2.000000  0.000000  2143.850000   4.500000   39.330000
# 9    0.000000  294.400000  0.000000   158.100000  21.600000   35.960000
# 10   1.300000    0.000000  0.000000   476.400000  65.000000  139.100000
#
#             超市           食堂
# id
# ...

# %%
y_train.head()
# Out:
# id
# 0     1
# 1     1
# 8     5
# 9     5
# 10    1
# Name: score_rank, dtype: int64

# %%
x_test.head()
# Out:
#      lib_times  borrow_total   con_val   其他    图书馆       开水   教务处   文印中心  校医院  \
# id
# 6     5.000000      2.000000   6284.83  0.0    2.2   839.01   0.0  14.52  0.0
# 7    91.000000     28.000000  11796.38  0.0   88.3  1033.74  11.4  10.30  0.0
# 12    6.000000     31.597342   9994.24  0.0  122.1   613.13   6.6   2.05  0.0
# 13  124.725151     31.597342    884.40  0.0    0.0     1.70   0.0   0.00  0.0
# 14  124.725151     31.597342    890.92  0.0    0.0     6.52   0.0   0.00  0.0
#
#         校车     洗衣房     淋浴       超市       食堂
# id
# 6    99.78    2.52    9.1   701.60  4616.10
# 7   602.64   54.00   21.4  1341.15  8633.45
# 12  259.83  105.60  228.5  2660.56  5995.87
# 13    0.00    0.00    0.0   291.50   591.20
# 14   11.60    0.00    0.4    53.90   818.50

# %%
x_train.fillna(x_train.mean(),inplace=True)
# Out:
#         lib_times  borrow_total       con_val         其他         图书馆  \
# id
# 0       16.000000     31.597342   7953.319141   2.310903  160.467910
# 1        2.000000     31.597342   5884.190000   0.000000  270.600000
# 8      124.725151     31.597342  10816.500000   0.000000  403.300000
# 9      124.725151     31.597342  14146.100000  61.130000  111.930000
# 10       4.000000     31.597342   5889.190000   0.000000  272.600000
# 11     124.725151      4.000000   5408.380000   0.000000  133.450000
# 19      19.000000     31.597342   3247.700000   0.000000   65.400000
# 20      14.000000      9.000000   6212.840000   0.000000   35.200000
# 21       5.000000     31.597342   3099.560000   0.000000   96.000000
# 22      19.000000      5.000000  10386.210000   0.000000  294.100000
# 23      14.000000     14.000000  10341.410000   0.000000   70.300000
# 28      63.000000      4.000000   6280.430000   0.000000  287.000000
# ...

# %%
x_train.isnull().sum()
# Out:
# lib_times       0
# borrow_total    0
# con_val         0
# 其他              0
# 图书馆             0
# 开水              0
# 教务处             0
# 文印中心            0
# 校医院             0
# 校车              0
# 洗衣房             0
# 淋浴              0
# 超市              0
# 食堂              0
# dtype: int64

# %%
x_test.fillna(x_test.mean(),inplace=True)
# Out:
#         lib_times  borrow_total   con_val      其他      图书馆       开水     教务处  \
# id
# 6        5.000000      2.000000   6284.83    0.00     2.20   839.01    0.00
# 7       91.000000     28.000000  11796.38    0.00    88.30  1033.74   11.40
# 12       6.000000     31.597342   9994.24    0.00   122.10   613.13    6.60
# 13     124.725151     31.597342    884.40    0.00     0.00     1.70    0.00
# 14     124.725151     31.597342    890.92    0.00     0.00     6.52    0.00
# 24     124.725151     31.597342   8575.91    0.00    97.20  1238.77    5.00
# 25     124.725151     31.597342    142.20    0.00     0.00    11.80    0.00
# 26     124.725151     31.597342    307.51    0.00     0.00    58.31    0.00
# 27      22.000000     31.597342   4691.21    0.00    92.10   429.44    0.00
# 30     126.000000     31.597342   5368.77  150.00   291.50   266.27    5.50
# 31      33.000000     31.597342   8845.79    0.00    74.70   511.14    9.10
# ...

# %%
x_test.isnull().sum()
# Out:
# lib_times       0
# borrow_total    0
# con_val         0
# 其他              0
# 图书馆             0
# 开水              0
# 教务处             0
# 文印中心            0
# 校医院             0
# 校车              0
# 洗衣房             0
# 淋浴              0
# 超市              0
# 食堂              0
# dtype: int64

# %%
y_train.isnull().sum()
# Out:
# 0

# %%
print(x_train.shape, y_train.shape,x_test.shape)
# Out:
# ((18336, 14), (18336,), (10961, 14))

# %%
x_train.to_pickle('./model_input/x_train.pkl')
y_train.to_pickle('./model_input/y_train.pkl')
x_test.to_pickle('./model_input/x_test.pkl')

# %%
import pandas as pd 
import warnings 
warnings.filterwarnings("ignore")
# card =  pd.read_csv("../data_processed/cleaned_card.csv",index_col='stu_id',encoding='utf-8')
card_data =  pd.read_csv('./reshaped_data/card_id_not_by_month.csv',index_col='id')
borrow_data =  pd.read_csv("./reshaped_data/borrow_total.csv",index_col='id')
library_data = pd.read_csv('./reshaped_data/lib_times.csv',index_col='id')

data = pd.concat([library_data,borrow_data,card_data],axis =1)

# %%
data.head(10)
# Out:
#     lib_times  borrow_total   con_val     其他     图书馆       开水   教务处    文印中心  \
# id
# 0        16.0           NaN       NaN    NaN     NaN      NaN   NaN     NaN
# 1         2.0           NaN   5884.19   0.00  270.60   262.79  29.3   96.40
# 6         5.0           2.0   6284.83   0.00    2.20   839.01   0.0   14.52
# 7        91.0          28.0  11796.38   0.00   88.30  1033.74  11.4   10.30
# 8         NaN           NaN  10816.50   0.00  403.30  2381.52   0.0    2.00
# 9         NaN           NaN  14146.10  61.13  111.93  4606.78   0.0  294.40
# 10        4.0           NaN   5889.19   0.00  272.60   743.40   1.3    0.00
# 11        NaN           4.0   5408.38   0.00  133.45   891.88   0.0    4.00
# 12        6.0           NaN   9994.24   0.00  122.10   613.13   6.6    2.05
# 13        NaN           NaN    884.40   0.00    0.00     1.70   0.0    0.00
#
#     校医院       校车     洗衣房      淋浴       超市       食堂
# id
# 0   NaN      NaN     NaN     NaN      NaN      NaN
# ...

# %%
data.isnull().sum()
# Out:
# lib_times       5205
# borrow_total    7336
# con_val            3
# 其他                 3
# 图书馆                3
# 开水                 3
# 教务处                3
# 文印中心               3
# 校医院                3
# 校车                 3
# 洗衣房                3
# 淋浴                 3
# 超市                 3
# 食堂                 3
# dtype: int64

# %%
#Replace with mean value
data.fillna(data.mean(), inplace=True)
data.isnull().sum()
# Out:
# lib_times       0
# borrow_total    0
# con_val         0
# 其他              0
# 图书馆             0
# 开水              0
# 教务处             0
# 文印中心            0
# 校医院             0
# 校车              0
# 洗衣房             0
# 淋浴              0
# 超市              0
# 食堂              0
# dtype: int64

# %%
data.head()
# Out:
#      lib_times  borrow_total       con_val        其他        图书馆           开水  \
# id
# 0    16.000000     31.597342   7953.319141  2.310903  160.46791   829.124677
# 1     2.000000     31.597342   5884.190000  0.000000  270.60000   262.790000
# 6     5.000000      2.000000   6284.830000  0.000000    2.20000   839.010000
# 7    91.000000     28.000000  11796.380000  0.000000   88.30000  1033.740000
# 8   124.725151     31.597342  10816.500000  0.000000  403.30000  2381.520000
#
#           教务处       文印中心       校医院           校车        洗衣房          淋浴  \
# id
# 0   15.720311  23.694739  4.371123   347.509772  58.996781  115.959425
# 1   29.300000  96.400000  0.000000   116.400000  34.800000   21.500000
# 6    0.000000  14.520000  0.000000    99.780000   2.520000    9.100000
# 7   11.400000  10.300000  0.000000   602.640000  54.000000   21.400000
# 8    0.000000   2.000000  0.000000  2143.850000   4.500000   39.330000
#
#              超市           食堂
# id
# 0    590.723995  5804.439505
# ...
